# %%
import pandas as pd
import numpy as np
import json

# %%
full_data = json.load(open("fakedata2.json"))

# %%
data = full_data["exam_18"]["std_44"]

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#         keystroke   mem_use        net_use  num_of_comp  time_spent  \
# 0.0          18.0  5.494107    7365.838380          NaN         NaN
# 10.0          6.0  5.306492   58733.620824          NaN         NaN
# 100.0         8.0  5.125185   92883.381061          NaN         NaN
# 1000.0       29.0  5.373092  228742.664221          NaN         NaN
# 1010.0       15.0  5.074747   29835.394110          NaN         NaN
# 1020.0       22.0  5.450964  143541.783089          NaN         NaN
# 1030.0        0.0  5.184909     743.333653          NaN         NaN
# 1040.0        4.0  5.384686  198315.265932          NaN         NaN
# 1050.0       23.0  5.474291  178351.689680          NaN         NaN
# 1060.0        8.0  5.324413  195266.107009          NaN         NaN
# 1070.0        1.0  5.150540   22779.221636          NaN         NaN
# 1080.0       20.0  5.083231  190901.404969          NaN         NaN
# 1090.0       27.0  5.190906   78079.345915          NaN         NaN
# ...

# %%
data["num_of_comp"]
# Out:
# {'r_q_1': 6,
#  'r_q_10': 3,
#  'r_q_2': 0,
#  'r_q_3': 5,
#  'r_q_4': 4,
#  'r_q_5': 7,
#  'r_q_6': 4,
#  'r_q_7': 6,
#  'r_q_8': 4,
#  'r_q_9': 7}
